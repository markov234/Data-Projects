# %%
# 9/18/24

# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import csv
import json
import os
from pandas import DataFrame, Series

import seaborn as sns

# %%
lego = pd.read_csv('lego_sets.csv')

lego.head()
# Out:
#   set_id                     name  year      theme     subtheme themeGroup  \
# 0    1-8          Small house set  1970  Minitalia          NaN    Vintage
# 1    2-8         Medium house set  1970  Minitalia          NaN    Vintage
# 2    3-6         Medium house set  1970  Minitalia          NaN    Vintage
# 3    4-4          Large house set  1970  Minitalia          NaN    Vintage
# 4    4-6  Mini House and Vehicles  1970  Samsonite  Model Maker    Vintage
#
#   category  pieces  minifigs  agerange_min  US_retailPrice  \
# 0   Normal    67.0       0.0           0.0             0.0
# 1   Normal   109.0       0.0           0.0             0.0
# 2   Normal   158.0       0.0           0.0             0.0
# 3   Normal   233.0       0.0           0.0             0.0
# 4   Normal     0.0       0.0           0.0             0.0
#
#                      bricksetURL  \
# 0  https://brickset.com/sets/1-8
# 1  https://brickset.com/sets/2-8
# 2  https://brickset.com/sets/3-6
# ...

# %%
lego.dtypes
# Out:
# set_id             object
# name               object
# year                int64
# theme              object
# subtheme           object
# themeGroup         object
# category           object
# pieces            float64
# minifigs          float64
# agerange_min      float64
# US_retailPrice    float64
# bricksetURL        object
# thumbnailURL       object
# imageURL           object
# dtype: object

# %%
lego.shape
# Out:
# (18457, 14)

# %%
# This code I used to change all the default NaN values to 0, specifically only in the 
# numeric columns, those being year, pieces, minifigs, agerange_min, and US_retailPrice.

# I did this because these columns were giving me trouble when I tried importing the data
# to MySQL.

# Don't need to run this cell again, because I saved the changes to the csv file.


# lego.fillna({'year': 0, 'pieces': 0, 'minifigs': 0, 'agerange_min': 0, 'US_retailPrice': 0}, inplace=True)
# lego.to_csv('lego_sets.csv', index=False)

# %%
lego.head()
# Out:
#   set_id                     name  year      theme     subtheme themeGroup  \
# 0    1-8          Small house set  1970  Minitalia          NaN    Vintage
# 1    2-8         Medium house set  1970  Minitalia          NaN    Vintage
# 2    3-6         Medium house set  1970  Minitalia          NaN    Vintage
# 3    4-4          Large house set  1970  Minitalia          NaN    Vintage
# 4    4-6  Mini House and Vehicles  1970  Samsonite  Model Maker    Vintage
#
#   category  pieces  minifigs  agerange_min  US_retailPrice  \
# 0   Normal    67.0       0.0           0.0             0.0
# 1   Normal   109.0       0.0           0.0             0.0
# 2   Normal   158.0       0.0           0.0             0.0
# 3   Normal   233.0       0.0           0.0             0.0
# 4   Normal     0.0       0.0           0.0             0.0
#
#                      bricksetURL  \
# 0  https://brickset.com/sets/1-8
# 1  https://brickset.com/sets/2-8
# 2  https://brickset.com/sets/3-6
# ...

# %%
medium_house_set_rows = lego[lego['name'] == 'Medium house set']
medium_house_set_rows
# Out:
#   set_id              name  year      theme subtheme themeGroup category  \
# 1    2-8  Medium house set  1970  Minitalia      NaN    Vintage   Normal
# 2    3-6  Medium house set  1970  Minitalia      NaN    Vintage   Normal
#
#    pieces  minifigs  agerange_min  US_retailPrice  \
# 1   109.0       0.0           0.0             0.0
# 2   158.0       0.0           0.0             0.0
#
#                      bricksetURL  \
# 1  https://brickset.com/sets/2-8
# 2  https://brickset.com/sets/3-6
#
#                                      thumbnailURL  \
# 1  https://images.brickset.com/sets/small/2-8.jpg
# 2  https://images.brickset.com/sets/small/3-6.jpg
#
#                                           imageURL
# 1  https://images.brickset.com/sets/images/2-8.jpg
# 2  https://images.brickset.com/sets/images/3-6.jpg
