# %%
# 10/23/24

# %%
# I will do some simple Python Pandas analysis of the data before I import it to Databricks for practice.

# %%
import requests
import pandas as pd

import csv
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

from math import radians, cos, sin, asin, sqrt
import json
import os
from pandas import DataFrame, Series

import numpy as np

# %%
# show all columns

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('old_yugioh_data.csv')

# %%
df
# Out:
#         card_id                            name            type  \
# 0      70781052                  Summoned Skull  Normal Monster
# 1      39111158               Tri-Horned Dragon  Normal Monster
# 2      89631139          Blue-Eyes White Dragon  Normal Monster
# 3      76184692                Hitotsu-Me Giant  Normal Monster
# 4      45231177                 Flame Swordsman  Fusion Monster
# ...         ...                             ...             ...
# 4711   68540059                      Metalmorph       Trap Card
# 4712   64335805     Red-Eyes Black Metal Dragon  Effect Monster
# 4713  111000561               Get Your Game On!      Spell Card
# 4714  501000006  Chimaera, the Master of Beasts  Effect Monster
# 4715  501000007            Emperor of Lightning  Effect Monster
#
#                                                    desc     atk     def  \
# 0     A fiend with dark powers for confusing the ene...  2500.0  1200.0
# 1     An unworthy dragon with three sharp horns spro...  2850.0  2350.0
# 2     This legendary dragon is a powerful engine of ...  3000.0  2500.0
# 3     A one-eyed behemoth with thick, powerful arms ...  1200.0  1000.0
# 4     "Flame Manipulator" + "Masaki the Legendary Sw...  1800.0  1600.0
# ...                                                 ...     ...     ...
# 4711  Target 1 face-up monster on the field; equip t...     NaN     NaN
# 4712  Cannot be Normal Summoned/Set. Must first be S...  2800.0  2400.0
# 4713  You can only play this card if you were presen...     NaN     NaN
# 4714  This card cannot be Special Summoned. To Tribu...  3000.0  3000.0
# 4715  This card cannot be Special Summoned. This car...  2600.0  2600.0
#
#       level           race attribute  scale  archetype  linkval  linkmarkers  \
# 0       6.0          Fiend      DARK    NaN  Archfiend      NaN          NaN
# 1       8.0         Dragon      DARK    NaN        NaN      NaN          NaN
# 2       8.0         Dragon     LIGHT    NaN  Blue-Eyes      NaN          NaN
# 3       4.0  Beast-Warrior     EARTH    NaN        NaN      NaN          NaN
# 4       5.0        Warrior      FIRE    NaN        NaN      NaN          NaN
# ...     ...            ...       ...    ...        ...      ...          ...
# 4711    NaN         Normal       NaN    NaN        NaN      NaN          NaN
# 4712    8.0        Machine      DARK    NaN   Red-Eyes      NaN          NaN
# 4713    NaN     Continuous       NaN    NaN        NaN      NaN          NaN
# 4714    9.0          Beast     LIGHT    NaN        NaN      NaN          NaN
# 4715    8.0        Thunder     LIGHT    NaN        NaN      NaN          NaN
#
#                                               image_url  \
# 0     https://images.ygoprodeck.com/images/cards/707...
# 1     https://images.ygoprodeck.com/images/cards/391...
# 2     https://images.ygoprodeck.com/images/cards/896...
# 3     https://images.ygoprodeck.com/images/cards/761...
# 4     https://images.ygoprodeck.com/images/cards/452...
# ...                                                 ...
# 4711  https://images.ygoprodeck.com/images/cards/685...
# 4712  https://images.ygoprodeck.com/images/cards/643...
# 4713  https://images.ygoprodeck.com/images/cards/111...
# 4714  https://images.ygoprodeck.com/images/cards/501...
# 4715  https://images.ygoprodeck.com/images/cards/501...
#
#                                         image_url_small ban_tcg ban_ocg  \
# 0     https://images.ygoprodeck.com/images/cards_sma...     NaN     NaN
# 1     https://images.ygoprodeck.com/images/cards_sma...     NaN     NaN
# 2     https://images.ygoprodeck.com/images/cards_sma...     NaN     NaN
# 3     https://images.ygoprodeck.com/images/cards_sma...     NaN     NaN
# 4     https://images.ygoprodeck.com/images/cards_sma...     NaN     NaN
# ...                                                 ...     ...     ...
# 4711  https://images.ygoprodeck.com/images/cards_sma...     NaN     NaN
# 4712  https://images.ygoprodeck.com/images/cards_sma...     NaN     NaN
# 4713  https://images.ygoprodeck.com/images/cards_sma...     NaN     NaN
# 4714  https://images.ygoprodeck.com/images/cards_sma...     NaN     NaN
# 4715  https://images.ygoprodeck.com/images/cards_sma...     NaN     NaN
#
#      ban_goat staple    views  viewsweek  upvotes  downvotes  \
# 0         NaN    NaN   461836          0       72         11
# 1         NaN    NaN   234847          0       34          2
# 2         NaN    NaN  2974079         52      423        154
# 3         NaN    NaN   248349          0       13          1
# 4         NaN    NaN   262094         52       27          2
# ...       ...    ...      ...        ...      ...        ...
# 4711      NaN    NaN   127512         26        9          3
# 4712      NaN    NaN    99345          0       12          8
# 4713      NaN    NaN     7631          0        4          2
# 4714      NaN    NaN    22785          0        4          1
# 4715      NaN    NaN    18887          0        2          0
#
#                                                 formats  \
# 0     GOAT|OCG GOAT|Duel Links|Common Charity|Speed ...
# 1     GOAT|OCG GOAT|Duel Links|Edison|TCG|OCG|Master...
# 2     GOAT|Speed Duel|OCG GOAT|Duel Links|Speed Duel...
# 3     GOAT|OCG GOAT|Duel Links|Common Charity|Edison...
# 4     GOAT|Speed Duel|OCG GOAT|Duel Links|Common Cha...
# ...                                                 ...
# 4711  GOAT|OCG GOAT|Speed Duel|Duel Links|Common Cha...
# 4712  GOAT|OCG GOAT|Duel Links|Common Charity|Edison...
# 4713                                 Common Charity|TCG
# 4714                                                TCG
# 4715                                                TCG
#
#                        treated_as card_tcg_date    ocg_date  konami_id  \
# 0                  Summoned Skull    2001-01-01  1999-07-22     4028.0
# 1                             NaN    2002-03-08  1999-08-26     4711.0
# 2          Blue-Eyes White Dragon    2002-03-08  1999-03-06     4007.0
# 3                             NaN    2002-03-08  1999-02-04     4009.0
# 4                 Flame Swordsman    2002-03-08  1999-03-06     4021.0
# ...                           ...           ...         ...        ...
# 4711                   Metalmorph    2002-11-25  1999-12-09     4664.0
# 4712  Red-Eyes Black Metal Dragon    2002-11-25  1999-12-09     4748.0
# 4713                          NaN    2007-07-28         NaN        NaN
# 4714                          NaN    2007-07-28         NaN     7374.0
# 4715                          NaN    2007-07-28         NaN     7375.0
#
#       has_effect                            set_id   set_rarity  \
# 0              0  a9cc1e0613d1b88098a29464879285a2       Common
# 1              0  8d1bb889266b35581fb2812b9d5f4013  Secret Rare
# 2              0  8d1bb889266b35581fb2812b9d5f4013   Ultra Rare
# 3              0  8d1bb889266b35581fb2812b9d5f4013       Common
# 4              0  8d1bb889266b35581fb2812b9d5f4013   Super Rare
# ...          ...                               ...          ...
# 4711           1  8e17cf648214fe19035492ab3a06baa8  Secret Rare
# 4712           1  8e17cf648214fe19035492ab3a06baa8  Secret Rare
# 4713           1  a186ea3ca338aa1962b8a2868bf4d557       Common
# 4714           1  a186ea3ca338aa1962b8a2868bf4d557   Ultra Rare
# 4715           1  a186ea3ca338aa1962b8a2868bf4d557   Ultra Rare
#
#      set_rarity_code                                       set_name  \
# 0                (C)         Summoned Skull Sample promotional card
# 1              (ScR)               Legend of Blue Eyes White Dragon
# 2               (UR)               Legend of Blue Eyes White Dragon
# 3                (C)               Legend of Blue Eyes White Dragon
# 4               (SR)               Legend of Blue Eyes White Dragon
# ...              ...                                            ...
# 4711           (ScR)                             Premium Pack (TCG)
# 4712           (ScR)                             Premium Pack (TCG)
# 4713             (C)  Yu-Gi-Oh! World Championship 2007 prize cards
# 4714            (UR)  Yu-Gi-Oh! World Championship 2007 prize cards
# 4715            (UR)  Yu-Gi-Oh! World Championship 2007 prize cards
#
#       num_of_cards set_tcg_date    set_code
# 0                1   2001-01-01     SDY-004
# 1              355   2002-03-08     LOB-000
# 2              355   2002-03-08     LOB-001
# 3              355   2002-03-08     LOB-002
# 4              355   2002-03-08     LOB-003
# ...            ...          ...         ...
# 4711            15   2007-07-26  PP01-EN014
# 4712            15   2007-07-26  PP01-EN015
# 4713             3   2007-07-28  WCPS-EN700
# 4714             3   2007-07-28  WCPS-EN701
# 4715             3   2007-07-28  WCPS-EN702
#
# [4716 rows x 36 columns]

# %%
# what are the dtypes of all the columsn

df.dtypes
# Out:
# card_id              int64
# name                object
# type                object
# desc                object
# atk                float64
# def                float64
# level              float64
# race                object
# attribute           object
# scale              float64
# archetype           object
# linkval            float64
# linkmarkers        float64
# image_url           object
# image_url_small     object
# ban_tcg             object
# ban_ocg             object
# ban_goat            object
# staple              object
# views                int64
# viewsweek            int64
# upvotes              int64
# downvotes            int64
# formats             object
# treated_as          object
# card_tcg_date       object
# ocg_date            object
# konami_id          float64
# has_effect           int64
# set_id              object
# set_rarity          object
# set_rarity_code     object
# set_name            object
# num_of_cards         int64
# set_tcg_date        object
# set_code            object
# dtype: object
