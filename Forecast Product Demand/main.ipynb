# %%
# 9/17/24

# Let me begin by exploring the data.

# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import csv
import json
import os
from pandas import DataFrame, Series

# %%
# Read the Historical Product Demand data
df = pd.read_csv('Historical Product Demand.csv')

# Display the first 5 rows of the data
df.head()
# Out:
#    Product_Code Warehouse Product_Category       Date Order_Demand
# 0  Product_0993    Whse_J     Category_028  2012/7/27         100
# 1  Product_0979    Whse_J     Category_028  2012/1/19         500
# 2  Product_0979    Whse_J     Category_028   2012/2/3         500
# 3  Product_0979    Whse_J     Category_028   2012/2/9         500
# 4  Product_0979    Whse_J     Category_028   2012/3/2         500

# %%
# Get the shape of the data
df.shape
# Out:
# (1048575, 5)

# %%
# Get the data types of the columns
df.dtypes
# Out:
# Product_Code        object
# Warehouse           object
# Product_Category    object
# Date                object
# Order_Demand        object
# dtype: object

# %%
# Let me convert Date and Order_Demand to datetime and integer data types respectively

# Convert the 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'], format='%Y/%m/%d')

# Convert the 'Order_Demand' column to integer format if it contains string values
if df['Order_Demand'].dtype == 'object':
    df['Order_Demand'] = df['Order_Demand'].str.replace('(', '').str.replace(')', '').astype(int)

df.head()
# Out:
#    Product_Code Warehouse Product_Category       Date  Order_Demand
# 0  Product_0993    Whse_J     Category_028 2012-07-27           100
# 1  Product_0979    Whse_J     Category_028 2012-01-19           500
# 2  Product_0979    Whse_J     Category_028 2012-02-03           500
# 3  Product_0979    Whse_J     Category_028 2012-02-09           500
# 4  Product_0979    Whse_J     Category_028 2012-03-02           500

# %%
# Double check the column types now to make sure they were properly converted.
df.dtypes
# Out:
# Product_Code                object
# Warehouse                   object
# Product_Category            object
# Date                datetime64[ns]
# Order_Demand                 int64
# dtype: object

# %%
# See how many unique values there are for each column.

for col in df.columns:
    print(col, df[col].nunique())
# Out:
# Product_Code 2160
# Warehouse 4
# Product_Category 33
# Date 1729
# Order_Demand 3320

# %%
# Now I want to make another column in the df that is the month of the order date.

# Extract the month and convert it to the month name
df['Order_Month'] = df['Date'].dt.month_name()

df.head()
# Out:
#    Product_Code Warehouse Product_Category       Date  Order_Demand  \
# 0  Product_0993    Whse_J     Category_028 2012-07-27           100
# 1  Product_0979    Whse_J     Category_028 2012-01-19           500
# 2  Product_0979    Whse_J     Category_028 2012-02-03           500
# 3  Product_0979    Whse_J     Category_028 2012-02-09           500
# 4  Product_0979    Whse_J     Category_028 2012-03-02           500
#
#   Order_Month
# 0        July
# 1     January
# 2    February
# 3    February
# 4       March

# %%
# Now I want to get the average Order_Demand for every Product_Code 
# in every Warehouse in every month.

grouped_df = df.groupby(['Product_Code', 'Warehouse', 'Order_Month'])['Order_Demand'].mean().reset_index()

grouped_df.rename(columns={'Order_Demand': 'Average_Order_Demand'}, inplace=True)

grouped_df.head(50)
# Out:
#     Product_Code Warehouse Order_Month  Average_Order_Demand
# 0   Product_0001    Whse_A       April           1836.363636
# 1   Product_0001    Whse_A      August           1575.000000
# 2   Product_0001    Whse_A    December           1038.461538
# 3   Product_0001    Whse_A    February           1486.363636
# 4   Product_0001    Whse_A     January           1106.250000
# 5   Product_0001    Whse_A        July           1700.000000
# 6   Product_0001    Whse_A        June           1388.235294
# 7   Product_0001    Whse_A       March           1709.523810
# 8   Product_0001    Whse_A         May           1657.142857
# 9   Product_0001    Whse_A    November           1566.666667
# 10  Product_0001    Whse_A     October           1740.000000
# 11  Product_0001    Whse_A   September           1375.000000
# 12  Product_0001    Whse_J       April            236.666667
# 13  Product_0001    Whse_J      August            358.333333
# 14  Product_0001    Whse_J    December            262.068966
# 15  Product_0001    Whse_J    February            272.222222
# 16  Product_0001    Whse_J     January            334.375000
# 17  Product_0001    Whse_J        July            289.473684
# 18  Product_0001    Whse_J        June            463.333333
# 19  Product_0001    Whse_J       March            302.380952
# 20  Product_0001    Whse_J         May            300.000000
# 21  Product_0001    Whse_J    November            369.230769
# 22  Product_0001    Whse_J     October            269.696970
# 23  Product_0001    Whse_J   September            229.629630
# 24  Product_0002    Whse_C       April           2222.222222
# 25  Product_0002    Whse_C      August           1833.333333
# 26  Product_0002    Whse_C    December           2187.500000
# 27  Product_0002    Whse_C    February           3571.428571
# 28  Product_0002    Whse_C     January           1000.000000
# 29  Product_0002    Whse_C        July           1916.666667
# 30  Product_0002    Whse_C        June           2300.000000
# 31  Product_0002    Whse_C       March           1250.000000
# 32  Product_0002    Whse_C         May           1062.500000
# 33  Product_0002    Whse_C    November           2500.000000
# 34  Product_0002    Whse_C     October           1642.857143
# 35  Product_0002    Whse_C   September           2500.000000
# 36  Product_0002    Whse_S       April          15200.000000
# 37  Product_0002    Whse_S      August          18568.965517
# 38  Product_0002    Whse_S    December          20961.538462
# 39  Product_0002    Whse_S    February          33926.829268
# 40  Product_0002    Whse_S     January          37878.787879
# 41  Product_0002    Whse_S        July          14656.250000
# 42  Product_0002    Whse_S        June          16400.000000
# 43  Product_0002    Whse_S       March          25683.333333
# 44  Product_0002    Whse_S         May          21041.666667
# 45  Product_0002    Whse_S    November          19568.965517
# 46  Product_0002    Whse_S     October          21913.043478
# 47  Product_0002    Whse_S   September          31435.483871
# 48  Product_0003    Whse_J       April            510.000000
# 49  Product_0003    Whse_J      August            372.222222

# %%
len(grouped_df)
# Out:
# 33246

# %%
# Are there any rows in df where 'Order_Demand' is 0?

df[df['Order_Demand'] == 0]
# Out:
#          Product_Code Warehouse Product_Category       Date  Order_Demand  \
# 46286    Product_0981    Whse_A     Category_028 2012-06-04             0
# 46287    Product_0981    Whse_A     Category_028 2012-06-08             0
# 68611    Product_1250    Whse_A     Category_019 2012-03-09             0
# 68613    Product_1250    Whse_A     Category_019 2012-05-01             0
# 68615    Product_1250    Whse_A     Category_019 2012-05-25             0
# ...               ...       ...              ...        ...           ...
# 1047529  Product_1378    Whse_J     Category_019 2016-08-31             0
# 1047683  Product_0955    Whse_J     Category_028 2016-03-29             0
# 1047684  Product_1030    Whse_J     Category_028 2016-03-29             0
# 1047685  Product_0955    Whse_J     Category_028 2016-09-26             0
# 1047686  Product_1030    Whse_J     Category_028 2016-09-26             0
#
#         Order_Month
# 46286          June
# 46287          June
# 68611         March
# 68613           May
# 68615           May
# ...             ...
# 1047529      August
# 1047683       March
# 1047684       March
# 1047685   September
# 1047686   September
#
# [28681 rows x 6 columns]

# %%
# Here is my conclusion for this dataset:

# To make a ML model, I would only be able to do it for a specific Product_Code,
# Warehouse, and Order_Month. There are only about 30-50 rows for each combination.

# If I'm trying to make ML models, I should use data that has more rows for each combination.

# But this is a good dataset to practice data cleaning and manipulation.
# I can use it to practice visualizing how data might look in the real world,
# where I don't have large amounts of records all the time.

# Something like the wine dataset would be better for practicing ML model making.
